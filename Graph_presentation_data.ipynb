# %% [markdown]
# <a href="https://colab.research.google.com/github/Duhnys/E11-Lab-Work/blob/main/Graph_presentation_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Moffit_data=pd.read_excel('Moffit-data.csv.xlsx')
print(Moffit_data)
# Out:
#      Latitude   Longitude  Radiation(cps)
# 0   37.872642 -122.260507               0
# 1   37.872743 -122.260567               2
# 2   37.872803 -122.260518               2
# 3   37.872892 -122.260642               2
# 4   37.872870 -122.260781               2
# 5   37.872828 -122.260953               1
# 6   37.872870 -122.260953               6
# 7   37.872841 -122.260652               7
# 8   37.872824 -122.260926               5
# 9   37.872790 -122.261044               3
# 10  37.872769 -122.261114               8
# 11  37.872752 -122.261194              10
# 12  37.872731 -122.261259               7
# 13  37.872681 -122.261329               5
# 14  37.872621 -122.261339              12
# 15  37.872541 -122.261355               4
# 16  37.872473 -122.261323               9
# 17  37.872418 -122.261280              13
# 18  37.872295 -122.261264              14
# 19  37.872228 -122.261216              14
# 20  37.872175 -122.261092              14
# ...

# %%
Moffit_data['Radiation(cps)'].plot()
Moffit_data['Latitude'].plot()
Moffit_data['Longitude'].plot()

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')
 
ax.scatter(37.872828,-122.260953,4)
ax.scatter(37.87287,-122.260953,4)
ax.scatter(37.872892,-122.260781,3)
ax.scatter(37.872743,-122.260642,5)
ax.scatter(37.872803,-122.260567,5)
ax.scatter(37.87279,-122.260518,3)
ax.scatter(37.872586,-122.261044,6)
ax.scatter(37.872497,-122.26047,8)
ax.scatter(37.872541,-122.261355,17) 
ax.scatter(37.872681,-122.261329,15)#11
ax.scatter(37.872824,-122.260926,15)
ax.scatter(37.872642,-122.260507,14)
ax.scatter(37.872421,-122.260405,15)
ax.scatter(37.87287,-122.260953,16)
ax.scatter(37.872731,-122.261259,17)
ax.scatter(37.872841,-122.260652,17)
ax.scatter(37.872332,-122.260577,17)
ax.scatter(37.872378,-122.260491,17)
ax.scatter(37.872769,-122.261114,18)
ax.scatter(37.872473,-122.261323,9)
ax.scatter(37.872752,-122.261194,18)
ax.scatter(37.872302,-122.260685,18)
ax.scatter(37.872302,-122.260685,18)
ax.scatter(37.872256,-122.26098,12)
ax.scatter(37.872302,-122.260888,12)
ax.scatter(37.872418,122.26128,13)
ax.scatter(37.872295,-122.261264,14)
ax.scatter(37.872228,-122.261216,14)
ax.scatter(37.872175,-122.261092,14)
ax.set_xlabel("Latitude")

ax.set_ylabel("Longitude")

ax.set_zlabel("Radiation (cps)")
ax.set_title('Moffitt Library Data')
plt.show()



plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(37.872579,-122.259625,9)
ax.scatter(37.872543,-122.259751,8	)
ax.scatter(37.872514,-122.259821,8)
ax.scatter(37.872488,-122.25995,9)
ax.scatter(37.872391,-122.260035,10	)
ax.scatter(37.872332,-122.26003,13	)
ax.scatter(37.87226,-122.260009,13)
ax.scatter(37.872184,-122.259966,13)
ax.scatter(37.872095,-122.259912,14)
ax.scatter(37.872023,-122.259858,15)
ax.scatter(37.871951,-122.259821,17)
ax.scatter(37.871874,-122.259799,17)
ax.scatter(37.871824,-122.259778,8)
ax.scatter(37.871772,-122.259772,8)
ax.scatter(37.87173,-122.25974,8)
ax.scatter(37.871734,-122.259552,18)
ax.scatter(37.871785,-122.259327,18)
ax.scatter(37.871831,-122.259139,6)
ax.scatter(37.871996,-122.258989,6)
ax.scatter(37.872174,-122.25908,9)
ax.scatter(37.872344,-122.259166,7)
ax.scatter(37.872538,-122.259209,12)
ax.scatter(37.872636,-122.259375,12)
ax.scatter(37.872619,-122.259477,11)
ax.scatter(37.87261,-122.259654,10)
ax.set_xlabel("Latitude")

ax.set_ylabel("Longitude")

ax.set_zlabel("Radiation (cps)")
ax.set_title('East Asian Library Data')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(37.873628,-122.260025,9)
ax.scatter(37.873759,-122.260117,11)
ax.scatter(37.873752,-122.260228,7)
ax.scatter(37.873722,-122.26033,8)
ax.scatter(37.873722,-122.260443,8)
ax.scatter(37.873684,-122.260502,5)
ax.scatter(37.873667,-122.260609,12)
ax.scatter(37.873667,-122.260609,12)
ax.scatter(37.873625,-122.260754,6)
ax.scatter(37.873557,-122.260797,11)
ax.scatter(37.873447,-122.260754,13)
ax.scatter(37.873447,-122.260754,13)
ax.scatter(37.873341,-122.260695,13)
ax.scatter(37.873312,-122.260631,9)
ax.scatter(37.873329,-122.260529,12)
ax.scatter(37.873367,-122.260378,5)
ax.scatter(37.873413,-122.26018,8)
ax.scatter(37.873464,-122.260024,12)
ax.scatter(37.873549,-122.25996,6)
ax.scatter(37.873638,-122.260056,10)

ax.set_xlabel("Latitude")

ax.set_ylabel("Longitude")

ax.set_zlabel("Radiation (cps)")

ax.set_title('East Asian Library Data')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(37.87411,-122.258222,6)
ax.scatter(37.874114,-122.258099,5)
ax.scatter(37.874102,-122.257986,10)
ax.scatter(37.874123,-122.257863,11)
ax.scatter(37.87417,-122.25782,11)
ax.scatter(37.874233,-122.257798,6)
ax.scatter(37.874309,-122.257836,8)
ax.scatter(37.874394,-122.257911,8)
ax.scatter(37.874441,-122.257997,9)
ax.scatter(37.87439,-122.258072,6)
ax.scatter(37.874373,-122.258147,4)
ax.scatter(37.87436,-122.258201,7)
ax.scatter(37.874352,-122.258244,8)
ax.scatter(37.874326,-122.258324,8)
ax.scatter(37.874297,-122.258394,10)
ax.scatter(37.874229,-122.258383,11)
ax.scatter(37.874182,-122.258362,11)
ax.scatter(37.874127,-122.25833,5)

ax.set_xlabel("Latitude")

ax.set_ylabel("Longitude")

ax.set_zlabel("Radiation (cps)")

ax.set_title('Engineering Library Data')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(37.871581,-122.257336,22)
ax.scatter(37.871648,-122.257353,21)
ax.scatter(37.871699,-122.257433,20)
ax.scatter(37.871674,-122.257476,18)
ax.scatter(37.871648,-122.257514,17)
ax.scatter(37.871606,-122.257546,17)
ax.scatter(37.871589,-122.257567,12)
ax.scatter(37.871525,-122.257573,13)
ax.scatter(37.874441,	-122.25754,14)
ax.scatter(37.871432,-122.257514,17)
ax.scatter(37.871394,-122.257487,21)
ax.scatter(37.871339,-122.257455,22)
ax.scatter(37.871331,-122.25739,22)
ax.scatter(37.871386,-122.257315,22)
ax.scatter(37.871478,-122.25731,18)
ax.scatter(37.871571,-122.25732,19)

ax.set_xlabel("Latitude")

ax.set_ylabel("Longitude")

ax.set_zlabel("Radiation (cps)")

ax.set_title('Ethnic Studies Library Data')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(37.870244,-122.256076,14)
ax.scatter(37.870282-122.256006,25)
ax.scatter(37.870337,-122.255931,17)
ax.scatter(37.87038,-122.255931,16)
ax.scatter(37.870439,-122.255958,24)
ax.scatter(37.870515,-122.255963,9)
ax.scatter(37.870587,-122.255984,15)
ax.scatter(37.870659,-122.256054,12)
ax.scatter(37.870638,-122.256129,18)
ax.scatter(37.870621,-122.256205,13)
ax.scatter(37.870663,-122.256274,14)
ax.scatter(37.870638,-122.256323,16)
ax.scatter(37.870596,-122.256342,14)
ax.scatter(37.870562,-122.256376,17)
ax.scatter(37.87049,-122.256324,25)
ax.scatter(37.870375,-122.256312,12)
ax.scatter(37.870337,-122.256301,25)
ax.scatter(37.870308,-122.25628,10)
ax.scatter(37.871274,-122.256364,25)
ax.scatter(37.870253,-122.256237,21)
ax.scatter(37.870236,-122.256172,14)
ax.scatter(37.870282,-122.256097,21)


ax.set_xlabel("Latitude")

ax.set_ylabel("Longitude")

ax.set_zlabel("Radiation (cps)")

ax.set_title('Music Library Data')
plt.show()
